# %% [markdown]
# ##### 1 Cargar este archivo en Python. Realizar estadísticas descriptivas básicas
# ![image.png](attachment:image.png)

# %%
import pandas as pd
#import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
archivo_csv=pd.read_csv("HRDataset_v14.csv")
archivo_csv
# Out:
#                 Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0         Adinolfi, Wilson  K  10026          0                0         1
# 1    Ait Sidi, Karthikeyan     10084          1                1         1
# 2           Akinkuolie, Sarah  10196          1                1         0
# 3                Alagbe,Trina  10088          1                1         0
# 4            Anderson, Carol   10069          0                2         0
# ..                        ...    ...        ...              ...       ...
# 306            Woodson, Jason  10135          0                0         1
# 307        Ybarra, Catherine   10301          0                0         0
# 308          Zamora, Jennifer  10010          0                0         0
# 309               Zhou, Julia  10043          0                0         0
# 310             Zima, Colleen  10271          0                4         0
#
# ...

# %%
archivo_csv.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
archivo_csv.describe()
# Out:
#               EmpID   MarriedID  MaritalStatusID    GenderID  EmpStatusID  \
# count    311.000000  311.000000       311.000000  311.000000   311.000000
# mean   10156.000000    0.398714         0.810289    0.434084     2.392283
# std       89.922189    0.490423         0.943239    0.496435     1.794383
# min    10001.000000    0.000000         0.000000    0.000000     1.000000
# 25%    10078.500000    0.000000         0.000000    0.000000     1.000000
# 50%    10156.000000    0.000000         1.000000    0.000000     1.000000
# 75%    10233.500000    1.000000         1.000000    1.000000     5.000000
# max    10311.000000    1.000000         4.000000    1.000000     5.000000
#
#            DeptID  PerfScoreID  FromDiversityJobFairID         Salary  \
# count  311.000000   311.000000              311.000000     311.000000
# mean     4.610932     2.977492                0.093248   69020.684887
# std      1.083487     0.587072                0.291248   25156.636930
# ...

# %%
#ejemplos de coidigos que voy a necesitar
#df_lluvias.index = df_lluvias['Year']
#df_lluvias = df_lluvias.drop('Year', axis='columns')

# %% [markdown]
# #### 2. Realizar un histograma con los salarios. Qué rango(s) de salarios son los más populares?

# %%
#(pag37)se construyen con ax.hist
#bins representa la cantidad de intervalos a construir

# %%
#pag 66, para ver histogramas con seaborn. 
#Con el parámetro kind='hist', Seaborn graficará un histograma.

# %%
#sns.set()
df_ejercicio = sns.load_dataset('exercise')
df_ejercicio = df_ejercicio.drop('Unnamed: 0', axis='columns')
df_ejercicio.head()
# Out:
#    id     diet  pulse    time  kind
# 0   1  low fat     85   1 min  rest
# 1   1  low fat     85  15 min  rest
# 2   1  low fat     88  30 min  rest
# 3   2  low fat     90   1 min  rest
# 4   2  low fat     92  15 min  rest

# %%
df_30_min = df_ejercicio[df_ejercicio['time'] == '30 min']
df_30_min.head()
# Out:
#     id     diet  pulse    time  kind
# 2    1  low fat     88  30 min  rest
# 5    2  low fat     93  30 min  rest
# 8    3  low fat     94  30 min  rest
# 11   4  low fat     83  30 min  rest
# 14   5  low fat     91  30 min  rest

# %%
ax = sns.displot(data=df_30_min, x='pulse', kind='hist', hue='diet', fill=True)
ax.set(xlabel='Frecuencia Cardíaca', ylabel='Densidad', title='Distribución  de las pulsaciones')
plt.figure()

# %%
ax = sns.displot(data=archivo_csv, x='Salary', kind='hist',bins=15, fill=True)
ax.set(xlabel='Salarios', ylabel='Densidad', title='Distribución  de Salarios')
plt.figure()

# %% [markdown]
# #### Los salarios más frecuentes están entre 50.000 y 100.000

# %% [markdown]
# #### 3 Realizar un gráfico de violín con los salarios, discriminados por género.

# %%
#https://seaborn.pydata.org/generated/seaborn.violinplot.html
#https://www.youtube.com/watch?v=PNNLefP974M

# %%
ax = sns.catplot(data=archivo_csv,kind='violin', y='Salary',x="GenderID",  split=True)
ax.set(ylabel='Salario', xlabel='Género', title='Distribución  de Salarios según género')
plt.figure()

# %% [markdown]
# #### 4 Graficar la serie de tiempo correspondiente a la fecha de contratación (DateofHire)

# %%
archivo_csv_con_index=archivo_csv
archivo_csv_con_index.index=archivo_csv_con_index["DateofHire"]
archivo_csv_con_index.head()
# Out:
#                        Employee_Name  EmpID  MarriedID  MaritalStatusID  \
# DateofHire
# 7/5/2011         Adinolfi, Wilson  K  10026          0                0
# 3/30/2015   Ait Sidi, Karthikeyan     10084          1                1
# 7/5/2011           Akinkuolie, Sarah  10196          1                1
# 1/7/2008                Alagbe,Trina  10088          1                1
# 7/11/2011           Anderson, Carol   10069          0                2
#
#             GenderID  EmpStatusID  DeptID  PerfScoreID  \
# DateofHire
# 7/5/2011           1            1       5            4
# 3/30/2015          1            5       3            3
# 7/5/2011           0            5       5            3
# 1/7/2008           0            1       5            3
# 7/11/2011          0            5       5            3
#
#             FromDiversityJobFairID  Salary  ...     ManagerName  ManagerID  \
# DateofHire                                  ...
# ...

# %%
archivo_csv_con_index["DateofHire"]
data_prueba=archivo_csv_con_index
data_prueba['year'] = pd.DatetimeIndex(data_prueba["DateofHire"]).year
data_prueba['year']
data_prueba.head()
# Out:
#                        Employee_Name  EmpID  MarriedID  MaritalStatusID  \
# DateofHire
# 7/5/2011         Adinolfi, Wilson  K  10026          0                0
# 3/30/2015   Ait Sidi, Karthikeyan     10084          1                1
# 7/5/2011           Akinkuolie, Sarah  10196          1                1
# 1/7/2008                Alagbe,Trina  10088          1                1
# 7/11/2011           Anderson, Carol   10069          0                2
#
#             GenderID  EmpStatusID  DeptID  PerfScoreID  \
# DateofHire
# 7/5/2011           1            1       5            4
# 3/30/2015          1            5       3            3
# 7/5/2011           0            5       5            3
# 1/7/2008           0            1       5            3
# 7/11/2011          0            5       5            3
#
#             FromDiversityJobFairID  Salary  ...  ManagerID  RecruitmentSource  \
# DateofHire                                  ...
# ...

# %%
x=data_prueba["year"]
y=data_prueba["Salary"]
fig, ax = plt.subplots(figsize=(12, 4))
ax.plot(x, y, label='Salario')

ax.set_xlabel('Fecha')
ax.set_ylabel('Salario')
ax.set_title('Gráfica de salarios con respecto a fecha de contratación con sólo el año')
ax.legend()

# %%
x=archivo_csv_con_index.index
y=archivo_csv_con_index["Salary"]
fig, ax = plt.subplots(figsize=(12, 4))
ax.plot(x, y, label='Salario')

ax.set_xlabel('Fecha')
ax.set_ylabel('Salario')
ax.set_title('Gráfica de salarios con respecto a fecha de contratación, incluyendo la fecha completa')
ax.legend()
