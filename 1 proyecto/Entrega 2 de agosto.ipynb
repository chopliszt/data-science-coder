# %%
#Análisis multivariado
#Dataset: https://www.kaggle.com/datasets/vipulgote4/reading-habit-dataset?resource=download

# %%
#this dataset contain how much amount of peoples read books or audiobooks and therir age,income ,Education etc.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('reading_habit.csv').rename(columns={'How many books did you read during last 12months?': 'books_read'})
df.dropna() #para evitar que hayan datos faltantes
df
# Out:
#       Age     Sex                             Race     Marital status?  \
# 0      66    Male                          Refused            Divorced
# 1      46    Male  Native American/American Indian             Married
# 2      32    Male                       Mixed race  Never been married
# 3      27    Male                       Mixed race             Married
# 4      16  Female                       Mixed race  Never been married
# ...   ...     ...                              ...                 ...
# 2827   18    Male                            White  Never been married
# 2828   17    Male                            White  Never been married
# 2829   17  Female                            White  Never been married
# 2830   16    Male                            White  Never been married
# 2831   16    Male                            White  Never been married
#
#                    Education           Employement  \
# 0           College graduate               Retired
# ...

# %%
df.rename(columns={'How many books did you read during last 12months?': 'books_read'}) #renombrando una columna para facilidad
# Out:
#       Age     Sex                             Race     Marital status?  \
# 0      66    Male                          Refused            Divorced
# 1      46    Male  Native American/American Indian             Married
# 2      32    Male                       Mixed race  Never been married
# 3      27    Male                       Mixed race             Married
# 4      16  Female                       Mixed race  Never been married
# ...   ...     ...                              ...                 ...
# 2827   18    Male                            White  Never been married
# 2828   17    Male                            White  Never been married
# 2829   17  Female                            White  Never been married
# 2830   16    Male                            White  Never been married
# 2831   16    Male                            White  Never been married
#
#                    Education           Employement  \
# 0           College graduate               Retired
# ...

# %%
df.shape
# Out:
# (2832, 14)

# %%
df.head()
# Out:
#    Age     Sex                             Race     Marital status?  \
# 0   66    Male                          Refused            Divorced
# 1   46    Male  Native American/American Indian             Married
# 2   32    Male                       Mixed race  Never been married
# 3   27    Male                       Mixed race             Married
# 4   16  Female                       Mixed race  Never been married
#
#                 Education         Employement                   Incomes  \
# 0        College graduate             Retired  $20,000 to under $30,000
# 1    High school graduate  Employed full-time         Less than $10,000
# 2    High school graduate  Employed full-time         Less than $10,000
# 3    High school graduate  Employed full-time  $40,000 to under $50,000
# 4  High school incomplete  Employed part-time  $10,000 to under $20,000
#
#    How many books did you read during last 12months?  \
# 0                                                 97
# ...

# %%
df.describe()
# Out:
#                Age  How many books did you read during last 12months?
# count  2832.000000                                        2832.000000
# mean     47.276483                                          16.676201
# std      18.565516                                          23.632071
# min      16.000000                                           0.000000
# 25%      32.000000                                           2.750000
# 50%      48.000000                                           6.000000
# 75%      62.000000                                          20.000000
# max      93.000000                                          97.000000

# %%
df.describe().T
# Out:
#                                                     count       mean  \
# Age                                                2832.0  47.276483
# How many books did you read during last 12months?  2832.0  16.676201
#
#                                                          std   min    25%  \
# Age                                                18.565516  16.0  32.00
# How many books did you read during last 12months?  23.632071   0.0   2.75
#
#                                                     50%   75%   max
# Age                                                48.0  62.0  93.0
# How many books did you read during last 12months?   6.0  20.0  97.0

# %%
df.count()
# Out:
# Age                                                    2832
# Sex                                                    2832
# Race                                                   2832
# Marital status?                                        2832
# Education                                              2832
# Employement                                            2832
# Incomes                                                2832
# How many books did you read during last 12months?      2832
# Read any printed books during last 12months?           2442
# Read any audiobooks during last 12months?              2442
# Read any e-books during last 12months?                 2442
# Last book you read, you…                               2442
# Do you happen to read any daily news or newspapers?    2832
# Do you happen to read any magazines or journals?       2832
# dtype: int64

# %%
df.dtypes
# Out:
# Age                                                     int64
# Sex                                                    object
# Race                                                   object
# Marital status?                                        object
# Education                                              object
# Employement                                            object
# Incomes                                                object
# How many books did you read during last 12months?       int64
# Read any printed books during last 12months?           object
# Read any audiobooks during last 12months?              object
# Read any e-books during last 12months?                 object
# Last book you read, you…                               object
# Do you happen to read any daily news or newspapers?    object
# Do you happen to read any magazines or journals?       object
# dtype: object

# %%
#Preparación de datos
reading_habits_dummy = pd.get_dummies(df)
reading_habits_dummy
# Out:
#       Age  How many books did you read during last 12months?  Sex_Female  \
# 0      66                                                 97           0
# 1      46                                                 97           0
# 2      32                                                 97           0
# 3      27                                                 97           0
# 4      16                                                 97           1
# ...   ...                                                ...         ...
# 2827   18                                                  0           0
# 2828   17                                                  0           0
# 2829   17                                                  0           1
# 2830   16                                                  0           0
# 2831   16                                                  0           0
#
#       Sex_Male  Race_Asian or Pacific Islander  \
# ...

# %%
#mostrando sólo una columna
df_traspuesta=df.T
df_traspuesta
# Out:
#       Age     Sex                             Race     Marital status?  \
# 0      66    Male                          Refused            Divorced
# 1      46    Male  Native American/American Indian             Married
# 2      32    Male                       Mixed race  Never been married
# 3      27    Male                       Mixed race             Married
# 4      16  Female                       Mixed race  Never been married
# ...   ...     ...                              ...                 ...
# 2827   18    Male                            White  Never been married
# 2828   17    Male                            White  Never been married
# 2829   17  Female                            White  Never been married
# 2830   16    Male                            White  Never been married
# 2831   16    Male                            White  Never been married
#
#                    Education           Employement  \
# 0           College graduate               Retired
# ...

# %%
df.rename(columns={'How many books did you read during last 12months?': 'books_read'})
# Out:
#       Age     Sex                             Race     Marital status?  \
# 0      66    Male                          Refused            Divorced
# 1      46    Male  Native American/American Indian             Married
# 2      32    Male                       Mixed race  Never been married
# 3      27    Male                       Mixed race             Married
# 4      16  Female                       Mixed race  Never been married
# ...   ...     ...                              ...                 ...
# 2827   18    Male                            White  Never been married
# 2828   17    Male                            White  Never been married
# 2829   17  Female                            White  Never been married
# 2830   16    Male                            White  Never been married
# 2831   16    Male                            White  Never been married
#
#                    Education           Employement  \
# 0           College graduate               Retired
# ...

# %%
df.head(50)
# Out:
#     Age     Sex                             Race        Marital status?  \
# 0    66    Male                          Refused               Divorced
# 1    46    Male  Native American/American Indian                Married
# 2    32    Male                       Mixed race     Never been married
# 3    27    Male                       Mixed race                Married
# 4    16  Female                       Mixed race     Never been married
# 5    55  Female        Asian or Pacific Islander               Divorced
# 6    63    Male        Black or African-American                Widowed
# 7    60  Female        Black or African-American                Married
# 8    50  Female        Black or African-American                Married
# 9    29  Female        Black or African-American     Never been married
# 10   23    Male        Black or African-American     Never been married
# 11   19  Female        Black or African-American     Never been married
# ...

# %%
#Gráfico, lo hago con edad y libros, porque las demás variables son categóricas
sns.scatterplot(data=df, x="Age", y="books_read")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='books_read'>

# %%
#Barplot

# %%
#https://datagy.io/seaborn-barplot/
plt.figure(figsize=(20,5))
sns.countplot(x='books_read',data=df)
plt.show()

# %%
#Distplot
#fig = plt.figure(figsize=(20,5))
sns.distplot(df.books_read, kde=True, label='Books Read')
# Out:
# C:\pythonjc\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='books_read', ylabel='Density'>
