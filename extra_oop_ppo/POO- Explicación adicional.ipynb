# %% [markdown]
# # PROGRAMACIÓN ORIENTADA A OBJETOS

# %% [markdown]
# Lo primero que queremos entender es qué es un objeto. Para ello, imaginemos que decidimos abir un hotel. Los clientes comienzan a llegar, y ahora tenemos muchas maletas en el lobby
# que los huéspedes esperan, se les lleve a sus habitaciones![gran-hotel-budapest-cartel-1513779850.jpg](attachment:gran-hotel-budapest-cartel-1513779850.jpg)

# %%
Entonces, necesitamos nuestro primer botones(que llamaremos también como botones_1): les presento a Felipe

# %% [markdown]
# ![bellboy.jpg](attachment:bellboy.jpg)

# %% [markdown]
# Felipe(botones_1) tiene 25 años, su apellido es Montes, habla inglés y español, tiene 2 años de experiencia, tiene permiso para trabajar y dentro de sus funciones están llevar maletas, saludar huéspedes en varios idiomas y recibir propinas

# %%
#En Python, así se ve la información que recibimos de él
botones_1_edad=25
botones_1_nombre= "Felipe"
botones_1_apellido= "Montes"
botones_1_idiomas= ["Inglés", "Español"]
botones_1_años_de_experiencia= 2
botones_1_tiene_permido_de_trabajar= True

# %%
#De esta forma, si le debemos dar un guion a Felipe para que salude a los huéspedes, podría verse así:
print(f"Buenos días, mi nombre es {botones_1_nombre} y les doy la bienvenida al hotel")
# Out:
# Buenos días, mi nombre es Felipe y les doy la bienvenida al hotel

# %% [markdown]
# Ahora imaginemos que el hotel comenzó a ser muy exitoso y comenzamos a tener muchos mpas clientes, tantos que ya Felipe no es suficiente. Entonces debemos traer 5 botones más: Camilo, Diego, Andrea, Gaby y Lara.

# %%
#Para crear nuestros nuevos botones, tendríamos que hacer algo así

#Información de Diego
botones_1_edad=28
botones_1_nombre= "Diego"
botones_1_apellido= "Fuentes"
botones_1_idiomas= ["Indonesio", "Español"]
botones_1_años_de_experiencia= 1
botones_1_tiene_permido_de_trabajar= True

#Información de Camilo
botones_2_edad=35
botones_2_nombre= "Camilo"
botones_2_apellido= "Mindernickel"
botones_2_idiomas= ["Inglés", "Español", "Francés", "Alemán", "Portugués"]
botones_2_años_de_experiencia= 0
botones_2_tiene_permido_de_trabajar= True

    
#Información de Andrea
botones_3_edad=21
botones_3_nombre= "Andrea"
botones_3_apellido= "Campos"
botones_3_idiomas= ["Inglés", "Español"]
botones_3_años_de_experiencia= 0
botones_3_tiene_permido_de_trabajar= True

#Información de Gaby
botones_4_edad=24
botones_4_nombre= "Gabrielle"
botones_4_apellido= "Baudelaire"
botones_4_idiomas= ["Inglés", "Español", "Francés", "Alemán", "Indonesio", "Japonés","Swahili"]
botones_4_años_de_experiencia= 0
botones_4_tiene_permido_de_trabajar= True


#Información de Lara
botones_5_edad=26
botones_5_nombre= "Lara"
botones_5_apellido= "Seufert"
botones_5_idiomas= ["Inglés", "Español", "Alemán"]
botones_5_años_de_experiencia= 4
botones_5_tiene_permido_de_trabajar= True

     
#Y cada vez que contraremos un nuevo botones, tendremos que crear las información de cada uno, como Diego y Camilo.
#Si nuestro hotel crece y necesitamos 10 botones, el código sería un dolor de cabeza
#Ahora, imagina que debemos agregar una nueva información de todos los botones como fecha de cumpleaños o,
#Imagina que cada año debemos modificar los años de experiencia y la edad de los botones. Tendríamos que hacerlo
#manualmente

# %%
#Cada vez que necesitemos imprimir información de cada uno de los botones vamos a tener que hacer algo así
#pidiendo información de Gaby
print(f"El nombre de nuestra botones 4 es {botones_4_nombre} y sus años de experiencia son {botones_4_años_de_experiencia}")
# Out:
# El nombre de neuestra botones 4 es Gabrielle y sus años de experiencia son 0

# %%
#Nota que en el anterior ejemplo se muestra que también debemos escribir cada variable

# %%
Como todos los botones tienen una información muy similar podemos llamar a cada uno un "Objeto". Cada persona es un "Objeto" 
que tiene la misma información. Los objetos necesitan dos cosas: 1)lo que tienen y 2)lo que hacen. A lo primero lo llamamos 
"atributos" y a lo que hacen, lo llamamos "metodos"

# %% [markdown]
# Podríamos crear manualmente cada uno de los objetos: botones_1,botones_2,botones_3,botones_4,botones_5,
# Pero en programación nos gusta evitar la repetición y buscar formas rápidas y fáciles de hacer las cosas

# %% [markdown]
# Algunos principios en programación son llamados como KISS, YAGNI, DRY..etc
# KISS: Keep It Simple Stupid
# YAGNI: You Ain’t Gonna need It
# DRY: Dont Repeat yourself
#
# En este ejemplo queremos utilizar el procipio DRY: no repitas

# %% [markdown]
# Entonces, en vez de crear objeto por objeto, vamos a crer una fábrica de objetos. En Python, una fábrica de objetos es llamada CLASE

# %%
Vamos ahora a crear la fábrica de botones!

# %%
#Recordemos la información de cada botones. Por ejemplo para Lara tenemos:
botones_5_edad=26
botones_5_nombre= "Lara"
botones_5_apellido= "Seufert"
botones_5_idiomas= ["Inglés", "Español", "Alemán"]
botones_5_años_de_experiencia= 4
botones_5_tiene_permido_de_trabajar= True

# %%
#en Python
class Botones :
    def __init__(self,edad,nombre,apellido,idiomas,experiencia,tiene_permido_de_trabajar):
        self.edad=edad
        self.nombre=nombre
        self.apellido=apellido
        self.idiomas=idiomas
        self.experiencia=experiencia
        self.tiene_permido_de_trabajar=tiene_permido_de_trabajar
        
    def saludar_en_esp(self):
        print(f"hola mi nombre es {self.nombre} y te doy la bienvenida al hotel")
    def pedir_propina(self):
        print(f"hola querido huesped, dado mi excelente servicio, puedes darme 200USD de propina")

# %%
#Usando neustra fabrica de Objetos Botones, vamos a crear neustro primer botones. Es así de fácil y rápido
botones_1=Botones(19,"Juan","Infante",["Italiano"],3,True)

# %%
#Ahora, colocando un punto después del objeto, podemos acceder a toda su información
print(f"La información de nuestro primer botones es Edad:{botones_1.edad},Nombre:{botones_1.nombre},Apellido:{botones_1.apellido}")
# Out:
# La información de nuestro primer botones es Edad:19,Nombre:Juan,Apellido:Infante

# %%
#Y así de fácil es crear nuestros 5 botones como antes
botones_1=Botones(19,"Felipe","Montes",["Inglés", "Español"],3,True)
botones_2=Botones(19,"Diego","Fuentes",["Indonesio", "Español"],3,True)
botones_3=Botones(19,"Camilo","Mindernickel",["Inglés", "Español", "Francés", "Alemán", "Portugués"],1,True)
botones_4=Botones(19,"Andrea","Campos",["Inglés", "Español"],0,True)
botones_5=Botones(19,"Gaby","Baudelaire",["Inglés", "Español", "Francés", "Alemán", "Indonesio", "Japonés","Swahili"],2,True)
botones_6=Botones(19,"Lara","Seufert",["Inglés", "Español", "Alemán"],0,True)

# %%
#tambien podemos pedirle a los botones que saluden, todo de una forma sencilla y rapida
botones_1.saludar_en_esp()
botones_2.saludar_en_esp()
botones_3.saludar_en_esp()
botones_4.saludar_en_esp()
botones_5.saludar_en_esp()
botones_6.saludar_en_esp()
# Out:
# hola mi nombre es Felipe y te doy la bienvenida al hotel
# hola mi nombre es Diego y te doy la bienvenida al hotel
# hola mi nombre es Camilo y te doy la bienvenida al hotel
# hola mi nombre es Andrea y te doy la bienvenida al hotel
# hola mi nombre es Gaby y te doy la bienvenida al hotel
# hola mi nombre es Lara y te doy la bienvenida al hotel

# %% [markdown]
# Ahora que vimos como crear nuestra fábrica(clase) de botones(objetos), vamos a ver un ejemplo con Pandas. Así como nosotros creamos nuestras clases, Pandas o Numpy tienen también algunas de ellas, creadas para que nosotros no tenegamos que reinventarnos la rueda(imagen de rueda) ¿te inventarías la rueda? Vamos a importar las librerías de Numpy y Pamdas
# Ahora, vamos a utilizar uno de los métodos(función asignada a un objeto).En este caso,

# %%
import pandas as pd

# %%
archivo_fuente=pd.read_csv('Summer-Olympic-medals-1976-to-2008.csv',encoding='iso-8859-1',index_col="Year")

# %% [markdown]
# Después de que escribimos "pd." , lo que viene es un método que los creadores de Pandas ya hicieron para nosotros y que nos permite leer archivos. Ese método se llama "read_csv" y para funcionar necesita recibir la ruta de un archivo csv

# %% [markdown]
# Ahora, vamos a utilizar el método head, de Pandas

# %%
archivo_fuente.head()
# Out:
#             City     Sport Discipline           Event  \
# Year
# 1976.0  Montreal  Aquatics     Diving  3m springboard
# 1976.0  Montreal  Aquatics     Diving  3m springboard
# 1976.0  Montreal  Aquatics     Diving  3m springboard
# 1976.0  Montreal  Aquatics     Diving  3m springboard
# 1976.0  Montreal  Aquatics     Diving    10m platform
#
#                          Athlete Gender Country_Code        Country  \
# Year
# 1976.0           KÖHLER, Christa  Women          GDR   East Germany
# 1976.0       KOSENKOV, Aleksandr    Men          URS   Soviet Union
# 1976.0      BOGGS, Philip George    Men          USA  United States
# 1976.0  CAGNOTTO, Giorgio Franco    Men          ITA          Italy
# 1976.0    WILSON, Deborah Keplar  Women          USA  United States
#
#        Event_gender   Medal
# Year
# 1976.0            W  Silver
# 1976.0            M  Bronze
# 1976.0            M    Gold
# 1976.0            M  Silver
# 1976.0            W  Bronze

# %% [markdown]
# Podemos usar este método, porque al igual que lo hicimos para nuestros Botones de hotel, un equipo de programadores de Pandas dejó muchas herramientas listas para nosotros utilizar
